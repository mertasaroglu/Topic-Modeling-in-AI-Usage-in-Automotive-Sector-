# %%
# === Cell 1: imports & paths ===
import os
import pandas as pd
from pathlib import Path

DATA_DIR = Path("../data")
DATA_DIR.mkdir(parents=True, exist_ok=True)

CORPUS_PATH = DATA_DIR / "df_corpus.parquet"

# %%
# === Cell 2: df_corpus'u yükle veya oluştur ===
# Eğer zaten parquet'in varsa:
#df_corpus = pd.read_parquet(CORPUS_PATH)

# Eğer yoksa, burada kaynak csv/parquet'leri okuyup concat edersin.
# Örn:
df_nasa = pd.read_csv(DATA_DIR / "nasaproject_corpus.csv")
df_news = pd.read_csv(DATA_DIR / "news_ai_corpus_2015_2025.csv")
df_paper = pd.read_csv(DATA_DIR / "paper_ai_corpus_2015_2025.csv")
df_patent  = pd.read_csv(DATA_DIR / "patent_ai_corpus_2015_2025.csv")
df_corpus = pd.concat([df_nasa, df_news, df_paper, df_patent], ignore_index=True)

df_corpus.head()
# Out:
#                                                title  \
# 0                               High TRL Rover Lidar
# 1  Standardizing a Data and Power System for GSFC...
# 2       Development of ACADIA-to-CCD Camera Platform
# 3  Atom Interferometer Gravity Gradiometer Techno...
# 4  Spaceflight Compatible Optical Atomic Strontiu...
#
#                                             abstract  \
# 0  Design and build a LIDAR engineering test unit...
# 1  There are three primary Tasks associated with ...
# 2  Develop a platform to adapt the Goddard-develo...
# 3  Cold atom interferometers enable measurements ...
# 4  Optical atomic clocks are critical tools for N...
#
#                                        detailed_text  year  month  \
# 0  The Space Qualified Rover Light Detection and ...  2024     10
# 1  To our knowledge, an NO2 sonde has never been ...  2024     10
# 2  The project will benefit systems and instrumen...  2024     10
# 3  The AIGG laser system lacks a path toward spac...  2024     10
# 4  OASIC leverages high accuracy timing and exqui...  2024     10
#
#     source_type                                         tech_field  trl
# 0  nasa_project      Sensing and Perception for Autonomous Systems  6.0
# 1  nasa_project                                Environment Sensors  7.0
# 2  nasa_project                         Detectors and Focal Planes  4.0
# 3  nasa_project                                             Lasers  4.0
# 4  nasa_project  Communications, Navigation, and Orbital Debris...  2.0

# %%
# === Cell 3: temel kolon kontrolleri ===
expected_cols = [
    "title", "abstract", "detailed_text",
    "year", "month",
    "source_type",   # 'nasa_project', 'news', 'paper', 'patent' gibi
    "tech_field",    # teknoloji alanı
    "trl"            # NASA'da dolu, diğerlerinde NaN
]

missing = [c for c in expected_cols if c not in df_corpus.columns]
print("Missing columns:", missing)
df_corpus.dtypes
# Out:
# Missing columns: []
# title             object
# abstract          object
# detailed_text     object
# year               int64
# month              int64
# source_type       object
# tech_field        object
# trl              float64
# dtype: object

# %%
# === Cell 4: text kolonu oluştur (title + abstract + detailed_text) ===
def safe_str(x):
    return "" if pd.isna(x) else str(x)

df_corpus["text"] = (
    df_corpus["title"].map(safe_str) + ". " +
    df_corpus["abstract"].map(safe_str) + " " +
    df_corpus["detailed_text"].map(safe_str)
).str.strip()

# TRL'yi float → int yap (varsa)
if "trl" in df_corpus.columns:
    df_corpus["trl"] = df_corpus["trl"].astype("float").round().astype("Int64")

df_corpus["source_type"] = df_corpus["source_type"].astype("string")
df_corpus["tech_field"]  = df_corpus["tech_field"].astype("string")
df_corpus["text"] = df_corpus["text"].astype("string")
df_corpus.sample(5)
# Out:
#                                                    title  \
# 21521  Ptc Is A Top Stock To Buy For Industrial Techn...
# 5760   MarsOasis - An Efficient Autonomously Controll...
# 9977   Automated High-Volume Manufacturing of Modular...
# 3960   Techniques to Support the Aerial Deployment an...
# 170                   End-to-End Trajectory Optimization
#
#                                                 abstract  \
# 21521  This computer-aided-design company has made bi...
# 5760   The MarsOasis™ cultivation system is a versati...
# 9977   Deployable Space Systems, Inc. (DSS) will focu...
# 3960   The proposed effort focuses on two critical ph...
# 170    Human exploration of the Solar System is in ou...
#
#                                            detailed_text  year  month  \
# 21521  This computer-aided-design company has made bi...  2022     12
# 5760   -MarsOasis™ provides fresh food to spacecraft ...  2024      1
# 9977   NASA space applications are comprised of pract...  2024      1
# 3960   The principal commercial application of this P...  2024      1
# 170    Why do we want end-to-end optimization? Tradit...  2024      7
#
#         source_type                                     tech_field   trl  \
# 21521          news                             internet_of_things  <NA>
# 5760   nasa_project  Food Production, Processing, and Preservation     5
# 9977   nasa_project                  Photovoltaic Electrical Power     4
# 3960   nasa_project                               Surface Mobility     6
# 170    nasa_project                 Trajectory Design and Analysis     5
#
#                                                     text
# 21521  Ptc Is A Top Stock To Buy For Industrial Techn...
# 5760   MarsOasis - An Efficient Autonomously Controll...
# 9977   Automated High-Volume Manufacturing of Modular...
# 3960   Techniques to Support the Aerial Deployment an...
# 170    End-to-End Trajectory Optimization. Human expl...

# %%
df_untechfield = df_corpus[df_corpus["tech_field"].isna()].copy()
df_untechfield
# Out:
#                                                    title  \
# 82     QuERI – Quantitative Elemental Reconnaissance ...
# 12414  Measurement of Secondary Electron Yield (SEY) ...
# 13769  Probing Exoplanet Atmospheric Physics with the...
# 13770  Rockets for Extended Source Soft X-ray Spectro...
# 13771  EUSO-SPB2: second generation Extreme Universe ...
# ...                                                  ...
# 24147  Accelerated Bayesian Calibration and Uncertain...
# 24148  An Approach to AI High-Velocity Development Th...
# 24149  Campus Resonance AI: A Recursive Communication...
# 24150                             The Wayfinder Protocol
# 24151  A Conceptual Framework for a Human Supervised ...
#
#                                                 abstract  \
# 82     Bulk geochemical analyses of planetary surface...
# 12414  Secondary Electron Yield (SEY) is a material p...
# 13769  We propose to build and fly the EXoplanet Infr...
# 13770  The soft X-ray background surrounds our local ...
# 13771  This is the lead Institution Co-Investigator P...
# ...                                                  ...
# 24147  Abstract In operational weather models, the ef...
# 24148  ABSTRACTAI-assisted development promises subst...
# 24149  CampusPulse AI: A Recursive Communication Arch...
# 24150  This is Draft 2 of The Wayfinder Protocol, a n...
# 24151  This work presents a conceptual framework for ...
#
#                                            detailed_text  year  month  \
# 82                                                   NaN  2024      9
# 12414                                                NaN  2023     12
# 13769                                                NaN  2022     11
# 13770                                                NaN  2022     11
# 13771                                                NaN  2022     11
# ...                                                  ...   ...    ...
# 24147  Abstract In operational weather models, the ef...  2025     11
# 24148  ABSTRACTAI-assisted development promises subst...  2025     11
# 24149  CampusPulse AI: A Recursive Communication Arch...  2025     11
# 24150  This is Draft 2 of The Wayfinder Protocol, a n...  2025     11
# 24151  This work presents a conceptual framework for ...  2025     11
#
#         source_type tech_field   trl  \
# 82     nasa_project       <NA>  <NA>
# 12414  nasa_project       <NA>  <NA>
# 13769  nasa_project       <NA>  <NA>
# 13770  nasa_project       <NA>  <NA>
# 13771  nasa_project       <NA>  <NA>
# ...             ...        ...   ...
# 24147         paper       <NA>  <NA>
# 24148         paper       <NA>  <NA>
# 24149         paper       <NA>  <NA>
# 24150         paper       <NA>  <NA>
# 24151         paper       <NA>  <NA>
#
#                                                     text
# 82     QuERI – Quantitative Elemental Reconnaissance ...
# 12414  Measurement of Secondary Electron Yield (SEY) ...
# 13769  Probing Exoplanet Atmospheric Physics with the...
# 13770  Rockets for Extended Source Soft X-ray Spectro...
# 13771  EUSO-SPB2: second generation Extreme Universe ...
# ...                                                  ...
# 24147  Accelerated Bayesian Calibration and Uncertain...
# 24148  An Approach to AI High-Velocity Development Th...
# 24149  Campus Resonance AI: A Recursive Communication...
# 24150  The Wayfinder Protocol. This is Draft 2 of The...
# 24151  A Conceptual Framework for a Human Supervised ...
#
# [463 rows x 9 columns]

# %%
df_corpus.dtypes
# Out:
# title                    object
# abstract                 object
# detailed_text            object
# year                      int64
# month                     int64
# source_type      string[python]
# tech_field       string[python]
# trl                       Int64
# text             string[python]
# dtype: object

# %%
# === Cell 5: NASA vs diğerlerini incele ===
df_nasa = df_corpus[df_corpus["source_type"] == "nasa_project"].copy()
df_unlabeled = df_corpus[df_corpus["trl"].isna()].copy()

print("Toplam:", len(df_corpus))
print("NASA:", len(df_nasa))
print("Label'sız:", len(df_unlabeled))

df_nasa["trl"].value_counts().sort_index()
# Out:
# Toplam: 25226
# NASA: 19631
# Label'sız: 10153
# trl
# 0      76
# 1     122
# 2     799
# 3    3615
# 4    4532
# 5    2528
# 6    2264
# 7     757
# 8     234
# 9     146
# Name: count, dtype: Int64

# %%
# === Cell 6: kaydet ===
df_corpus.to_parquet(CORPUS_PATH, index=False)
print("Saved to:", CORPUS_PATH)
# Out:
# Saved to: ..\data\df_corpus.parquet
